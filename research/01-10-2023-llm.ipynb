# %% [markdown]
# # **Item 3 - Sobre GenAI e LLMs**

# %% [markdown]
# ## Problema
#
# <p align="justify"> O Dataset disponibilizado tem 2 colunas de texto, uma de título e outra de descrição. Utilize um LLM - como  ChatGPT ou Claude - para criar features dos produtos que serão úteis para análise. </p>

# %% [markdown]
# <a name='1'></a>
#
# ## 1 - Carregando dados e modelo

# %%
from datasets import load_dataset
from transformers import AutoModelForSeq2SeqLM, GenerationConfig, TrainingArguments, Trainer, AutoTokenizer, AutoModel
import torch
import os
import time
import evaluate
import pandas as pd
import numpy as np

# %%
os.chdir("..")

# %% [markdown]
# <a name='1.1'></a>
# ### 1.2 - Dataset e LLM loading
#
# Carregando os dados localmente.

# %%
import os
import pyarrow as pa

# Defina o caminho para a pasta onde os arquivos Arrow estão localizados
folder_path = "artifacts/data_ingestion"

# Liste os arquivos na pasta
file_list = [f for f in os.listdir(folder_path) if f.endswith(".arrow")]

# Leia cada arquivo Arrow
for file_name in file_list:
    file_path = os.path.join(folder_path, file_name)
    table = pa.ipc.RecordBatchFileReader(file_path).read_all()
    
    # Faça o que você precisa com a tabela, por exemplo, converta-a para um DataFrame
    df = table.to_pandas()
    
    # Agora você pode trabalhar com o DataFrame df

    print(f"Leu o arquivo: {file_name}")

# %%
dataset = load_dataset("spacemanidol/product-search-corpus", 
                       split="train")
dataset
# Out:
# Dataset({
#     features: ['docid', 'title', 'text'],
#     num_rows: 1118658
# })

# %%
tokenizer = AutoTokenizer.from_pretrained("spacemanidol/trec-product-search-all-miniLM-L6-v2")
model = AutoModel.from_pretrained("spacemanidol/trec-product-search-all-miniLM-L6-v2")

# %% [markdown]
# <a name='1.2'></a>
# ### 1.2 - Testando o modelo com Zero Shot Inferencing
#
#
# Testando o modelo com zero shot inferencing, podemos ver que o modelo se esforça para resumir o diálogo em comparação com o resumo da linha de base, e extrai algumas informações importantes do texto, o que indica que o modelo pode ser ajustado para a tarefa em questão.

# %%
index = 2

# %%
title = dataset[index]["title"]

# %%
category = "Phone Accessories"

# %%
# Montar o prompt de classificação de texto
prompt = f"Classify the following product title into its category:\n\n{title}\n\nCandidate categories: Supplies, Phone Accessories, Clothing, Book, Electronics, Shoes, and others."

# prompt = f"Do whatever {title}"

# %%
# Tokenizar o prompt e codificá-lo para uso com o modelo
inputs = tokenizer(prompt, return_tensors="pt")

# %%
# # Executar a classificação de texto
# with torch.no_grad():
#     outputs = model(**inputs)
#     logits = outputs.logits

# # Obter a classe prevista
# predicted_class = torch.argmax(logits, dim=1).item()

# %%
# Obter o pooler_output após a passagem pelo modelo
with torch.no_grad():
    model_outputs = model(**inputs)
    pooler_output = model_outputs.pooler_output

# %%
#  Adicionar uma camada de classificação personalizada
class CustomClassifier(torch.nn.Module):
    def __init__(self):
        super(CustomClassifier, self).__init__()
        self.num_classes = 5  # Defina o número correto de classes aqui
        self.classifier = torch.nn.Linear(model.config.hidden_size, self.num_classes)

    def forward(self, pooled_output):
        return self.classifier(pooled_output)

# %%
classifier = CustomClassifier()
outputs = classifier(pooler_output)

# Obter a classe prevista
predicted_class = torch.argmax(outputs, dim=1).item()

# %%
predicted_class
# Out:
# 4

# %% [markdown]
# ## O dataset é extraído da Amazon, por isso agrupei essas categorias.

# %%
tokenizer = AutoTokenizer.from_pretrained("spacemanidol/trec-product-search-bge-base-en")
model = AutoModel.from_pretrained("spacemanidol/trec-product-search-bge-base-en")
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 366/366 [00:00<00:00, 508kB/s]
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 1.78MB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 711k/711k [00:00<00:00, 5.20MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 125/125 [00:00<00:00, 99.7kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 735/735 [00:00<00:00, 964kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 438M/438M [00:39<00:00, 11.1MB/s]

# %%
if torch.cuda.is_available():
    # Mova o modelo para a GPU
    model.to('cuda')
    
    # Criar uma lista para armazenar as previsões
    predictions = []
    
    categories = {
                0: "Food",
                1: "Health, Beauty",
                2: "Electronics, Computers",
                3: "Home and Kitchen",
                4: "Clothing",
                5: "Sports",
                6: "Office",
                7: "Movies, Music",
                8: "Books"     
            }
    # Iterar sobre todos os exemplos no seu conjunto de dados
    for i, example in enumerate(dataset):
        title = example["title"]

        # Montar o prompt de classificação de texto
        prompt = f"Classify the following product title into its category:\n\n{title}\n\nCandidate categories: {list(categories.values())}."

        # Tokenizar o prompt e codificá-lo para uso com o modelo
        inputs = tokenizer(prompt, return_tensors="pt").to('cuda')  # Mova os inputs para a GPU
        
        # Obter o pooler_output após a passagem pelo modelo
        with torch.no_grad():
            model_outputs = model(**inputs)
            pooler_output = model_outputs.pooler_output
        
        # Adicionar uma camada de classificação personalizada
        class CustomClassifier(torch.nn.Module):
            def __init__(self):
                super(CustomClassifier, self).__init__()
                self.num_classes = 5  # Defina o número correto de classes aqui
                self.classifier = torch.nn.Linear(model.config.hidden_size, self.num_classes).to('cuda')  # Mova o classificador para a GPU

            def forward(self, pooled_output):
                return self.classifier(pooled_output)
        
        classifier = CustomClassifier()
        outputs = classifier(pooler_output)
        
        # Obter a classe prevista
        predicted_class = torch.argmax(outputs, dim=1).item()
        
        # Armazenar a previsão na lista de previsões
        predictions.append(predicted_class)
        predicted_categories = [categories[index] for index in predictions]
        
        # Imprimir o número atual do exemplo processado
        print(f"Exemplo {i + 1}/{len(dataset)} processado")

else:
    print("GPU não disponível. Usando CPU.")
# Out:
# Exemplo 1/1118658 processado
# Exemplo 2/1118658 processado
# Exemplo 3/1118658 processado
# Exemplo 4/1118658 processado
# Exemplo 5/1118658 processado
# Exemplo 6/1118658 processado
# Exemplo 7/1118658 processado
# Exemplo 8/1118658 processado
# Exemplo 9/1118658 processado
# Exemplo 10/1118658 processado
# Exemplo 11/1118658 processado
# Exemplo 12/1118658 processado
# Exemplo 13/1118658 processado
# Exemplo 14/1118658 processado
# Exemplo 15/1118658 processado
# Exemplo 16/1118658 processado
# Exemplo 17/1118658 processado
# Exemplo 18/1118658 processado
# Exemplo 19/1118658 processado
# Exemplo 20/1118658 processado
# Exemplo 21/1118658 processado
# Exemplo 22/1118658 processado
# Exemplo 23/1118658 processado
# Exemplo 24/1118658 processado
# Exemplo 25/1118658 processado
# Exemplo 26/1118658 processado
# Exemplo 27/1118658 processado
# Exemplo 28/1118658 processado
# Exemplo 29/1118658 processado
# Exemplo 30/1118658 processado
# Exemplo 31/1118658 processado
# Exemplo 32/1118658 processado
# Exemplo 33/1118658 processado
# Exemplo 34/1118658 processado
# Exemplo 35/1118658 processado
# Exemplo 36/1118658 processado
# Exemplo 37/1118658 processado
# Exemplo 38/1118658 processado
# Exemplo 39/1118658 processado
# Exemplo 40/1118658 processado
# Exemplo 41/1118658 processado
# Exemplo 42/1118658 processado
# Exemplo 43/1118658 processado
# Exemplo 44/1118658 processado
# Exemplo 45/1118658 processado
# Exemplo 46/1118658 processado
# Exemplo 47/1118658 processado
# Exemplo 48/1118658 processado
# Exemplo 49/1118658 processado
# Exemplo 50/1118658 processado
# Exemplo 51/1118658 processado
# Exemplo 52/1118658 processado
# Exemplo 53/1118658 processado
# Exemplo 54/1118658 processado
# Exemplo 55/1118658 processado
# Exemplo 56/1118658 processado
# Exemplo 57/1118658 processado
# Exemplo 58/1118658 processado
# Exemplo 59/1118658 processado
# Exemplo 60/1118658 processado
# Exemplo 61/1118658 processado
# Exemplo 62/1118658 processado
# Exemplo 63/1118658 processado
# Exemplo 64/1118658 processado
# Exemplo 65/1118658 processado
# Exemplo 66/1118658 processado
# Exemplo 67/1118658 processado
# Exemplo 68/1118658 processado
# Exemplo 69/1118658 processado
# Exemplo 70/1118658 processado
# Exemplo 71/1118658 processado
# Exemplo 72/1118658 processado
# Exemplo 73/1118658 processado
# Exemplo 74/1118658 processado
# Exemplo 75/1118658 processado
# Exemplo 76/1118658 processado
# Exemplo 77/1118658 processado
# Exemplo 78/1118658 processado
# Exemplo 79/1118658 processado
# Exemplo 80/1118658 processado
# Exemplo 81/1118658 processado
# Exemplo 82/1118658 processado
# Exemplo 83/1118658 processado
# Exemplo 84/1118658 processado
# Exemplo 85/1118658 processado
# Exemplo 86/1118658 processado
# Exemplo 87/1118658 processado
# Exemplo 88/1118658 processado
# Exemplo 89/1118658 processado
# Exemplo 90/1118658 processado
# Exemplo 91/1118658 processado
# Exemplo 92/1118658 processado
# Exemplo 93/1118658 processado
# Exemplo 94/1118658 processado
# Exemplo 95/1118658 processado
# Exemplo 96/1118658 processado
# Exemplo 97/1118658 processado
# Exemplo 98/1118658 processado
# Exemplo 99/1118658 processado
# Exemplo 100/1118658 processado
# Exemplo 101/1118658 processado
# Exemplo 102/1118658 processado
# Exemplo 103/1118658 processado
# Exemplo 104/1118658 processado
# Exemplo 105/1118658 processado
# Exemplo 106/1118658 processado
# Exemplo 107/1118658 processado
# Exemplo 108/1118658 processado
# Exemplo 109/1118658 processado
# Exemplo 110/1118658 processado
# Exemplo 111/1118658 processado
# Exemplo 112/1118658 processado
# Exemplo 113/1118658 processado
# Exemplo 114/1118658 processado
# Exemplo 115/1118658 processado
# Exemplo 116/1118658 processado
# Exemplo 117/1118658 processado
# Exemplo 118/1118658 processado
# Exemplo 119/1118658 processado
# Exemplo 120/1118658 processado
# Exemplo 121/1118658 processado
# Exemplo 122/1118658 processado
# Exemplo 123/1118658 processado
# Exemplo 124/1118658 processado
# Exemplo 125/1118658 processado
# Exemplo 126/1118658 processado
# Exemplo 127/1118658 processado
# Exemplo 128/1118658 processado
# Exemplo 129/1118658 processado
# Exemplo 130/1118658 processado
# Exemplo 131/1118658 processado
# Exemplo 132/1118658 processado
# Exemplo 133/1118658 processado
# Exemplo 134/1118658 processado
# Exemplo 135/1118658 processado
# Exemplo 136/1118658 processado
# Exemplo 137/1118658 processado
# Exemplo 138/1118658 processado
# Exemplo 139/1118658 processado
# Exemplo 140/1118658 processado
# Exemplo 141/1118658 processado
# Exemplo 142/1118658 processado
# Exemplo 143/1118658 processado
# Exemplo 144/1118658 processado
# Exemplo 145/1118658 processado
# Exemplo 146/1118658 processado
# Exemplo 147/1118658 processado
# Exemplo 148/1118658 processado
# Exemplo 149/1118658 processado
# Exemplo 150/1118658 processado
# Exemplo 151/1118658 processado
# Exemplo 152/1118658 processado
# Exemplo 153/1118658 processado
# Exemplo 154/1118658 processado
# Exemplo 155/1118658 processado
# Exemplo 156/1118658 processado
# Exemplo 157/1118658 processado
# Exemplo 158/1118658 processado
# Exemplo 159/1118658 processado
# Exemplo 160/1118658 processado
# Exemplo 161/1118658 processado
# Exemplo 162/1118658 processado
# Exemplo 163/1118658 processado
# Exemplo 164/1118658 processado
# Exemplo 165/1118658 processado
# Exemplo 166/1118658 processado
# Exemplo 167/1118658 processado
# Exemplo 168/1118658 processado
# Exemplo 169/1118658 processado
# Exemplo 170/1118658 processado
# Exemplo 171/1118658 processado
# Exemplo 172/1118658 processado
# Exemplo 173/1118658 processado
# Exemplo 174/1118658 processado
# Exemplo 175/1118658 processado
# Exemplo 176/1118658 processado
# Exemplo 177/1118658 processado
# Exemplo 178/1118658 processado
# Exemplo 179/1118658 processado
# Exemplo 180/1118658 processado
# Exemplo 181/1118658 processado
# Exemplo 182/1118658 processado
# Exemplo 183/1118658 processado
# Exemplo 184/1118658 processado
# Exemplo 185/1118658 processado
# Exemplo 186/1118658 processado
# Exemplo 187/1118658 processado
# Exemplo 188/1118658 processado
# Exemplo 189/1118658 processado
# Exemplo 190/1118658 processado
# Exemplo 191/1118658 processado
# Exemplo 192/1118658 processado
# Exemplo 193/1118658 processado
# Exemplo 194/1118658 processado
# Exemplo 195/1118658 processado
# Exemplo 196/1118658 processado
# Exemplo 197/1118658 processado
# Exemplo 198/1118658 processado
# Exemplo 199/1118658 processado
# Exemplo 200/1118658 processado
# Exemplo 201/1118658 processado
# Exemplo 202/1118658 processado
# Exemplo 203/1118658 processado
# Exemplo 204/1118658 processado
# Exemplo 205/1118658 processado
# Exemplo 206/1118658 processado
# Exemplo 207/1118658 processado
# Exemplo 208/1118658 processado
# Exemplo 209/1118658 processado
# Exemplo 210/1118658 processado
# Exemplo 211/1118658 processado
# Exemplo 212/1118658 processado
# Exemplo 213/1118658 processado
# Exemplo 214/1118658 processado
# Exemplo 215/1118658 processado
# Exemplo 216/1118658 processado
# Exemplo 217/1118658 processado
# Exemplo 218/1118658 processado
# Exemplo 219/1118658 processado
# Exemplo 220/1118658 processado
# Exemplo 221/1118658 processado
# Exemplo 222/1118658 processado
# Exemplo 223/1118658 processado
# Exemplo 224/1118658 processado
# Exemplo 225/1118658 processado
# Exemplo 226/1118658 processado
# Exemplo 227/1118658 processado
# Exemplo 228/1118658 processado
# Exemplo 229/1118658 processado
# Exemplo 230/1118658 processado
# Exemplo 231/1118658 processado
# Exemplo 232/1118658 processado
# Exemplo 233/1118658 processado
# Exemplo 234/1118658 processado
# Exemplo 235/1118658 processado
# Exemplo 236/1118658 processado
# Exemplo 237/1118658 processado
# Exemplo 238/1118658 processado
# Exemplo 239/1118658 processado
# Exemplo 240/1118658 processado
# Exemplo 241/1118658 processado
# Exemplo 242/1118658 processado
# Exemplo 243/1118658 processado
# Exemplo 244/1118658 processado
# Exemplo 245/1118658 processado
# Exemplo 246/1118658 processado
# Exemplo 247/1118658 processado
# Exemplo 248/1118658 processado
# Exemplo 249/1118658 processado
# Exemplo 250/1118658 processado
# Exemplo 251/1118658 processado
# Exemplo 252/1118658 processado
# Exemplo 253/1118658 processado
# Exemplo 254/1118658 processado
# Exemplo 255/1118658 processado
# Exemplo 256/1118658 processado
# Exemplo 257/1118658 processado
# Exemplo 258/1118658 processado
# Exemplo 259/1118658 processado
# Exemplo 260/1118658 processado
# Exemplo 261/1118658 processado
# Exemplo 262/1118658 processado
# Exemplo 263/1118658 processado
# Exemplo 264/1118658 processado
# Exemplo 265/1118658 processado
# Exemplo 266/1118658 processado
# Exemplo 267/1118658 processado
# Exemplo 268/1118658 processado
# Exemplo 269/1118658 processado
# Exemplo 270/1118658 processado
# Exemplo 271/1118658 processado
# Exemplo 272/1118658 processado
# Exemplo 273/1118658 processado
# Exemplo 274/1118658 processado
# Exemplo 275/1118658 processado
# Exemplo 276/1118658 processado
# Exemplo 277/1118658 processado
# Exemplo 278/1118658 processado
# Exemplo 279/1118658 processado
# Exemplo 280/1118658 processado
# Exemplo 281/1118658 processado
# Exemplo 282/1118658 processado
# Exemplo 283/1118658 processado
# Exemplo 284/1118658 processado
# Exemplo 285/1118658 processado
# Exemplo 286/1118658 processado
# Exemplo 287/1118658 processado
# Exemplo 288/1118658 processado
# Exemplo 289/1118658 processado
# Exemplo 290/1118658 processado
# Exemplo 291/1118658 processado
# Exemplo 292/1118658 processado
# Exemplo 293/1118658 processado
# Exemplo 294/1118658 processado
# Exemplo 295/1118658 processado
# Exemplo 296/1118658 processado
# Exemplo 297/1118658 processado
# Exemplo 298/1118658 processado
# Exemplo 299/1118658 processado
# Exemplo 300/1118658 processado
# Exemplo 301/1118658 processado
# Exemplo 302/1118658 processado
# Exemplo 303/1118658 processado
# Exemplo 304/1118658 processado
# Exemplo 305/1118658 processado
# Exemplo 306/1118658 processado
# Exemplo 307/1118658 processado
# Exemplo 308/1118658 processado
# Exemplo 309/1118658 processado
# Exemplo 310/1118658 processado
# Exemplo 311/1118658 processado
# Exemplo 312/1118658 processado
# Exemplo 313/1118658 processado
# Exemplo 314/1118658 processado
# Exemplo 315/1118658 processado
# Exemplo 316/1118658 processado
# Exemplo 317/1118658 processado
# Exemplo 318/1118658 processado
# Exemplo 319/1118658 processado
# Exemplo 320/1118658 processado
# Exemplo 321/1118658 processado
# Exemplo 322/1118658 processado
# Exemplo 323/1118658 processado
# Exemplo 324/1118658 processado
# Exemplo 325/1118658 processado
# Exemplo 326/1118658 processado
# Exemplo 327/1118658 processado
# Exemplo 328/1118658 processado
# Exemplo 329/1118658 processado
# Exemplo 330/1118658 processado
# Exemplo 331/1118658 processado
# Exemplo 332/1118658 processado
# Exemplo 333/1118658 processado
# Exemplo 334/1118658 processado
# Exemplo 335/1118658 processado
# Exemplo 336/1118658 processado
# Exemplo 337/1118658 processado
# Exemplo 338/1118658 processado
# Exemplo 339/1118658 processado
# Exemplo 340/1118658 processado
# Exemplo 341/1118658 processado
# Exemplo 342/1118658 processado
# Exemplo 343/1118658 processado
# Exemplo 344/1118658 processado
# Exemplo 345/1118658 processado
# Exemplo 346/1118658 processado
# Exemplo 347/1118658 processado
# Exemplo 348/1118658 processado
# Exemplo 349/1118658 processado
# Exemplo 350/1118658 processado
# Exemplo 351/1118658 processado
# Exemplo 352/1118658 processado
# Exemplo 353/1118658 processado
# Exemplo 354/1118658 processado
# Exemplo 355/1118658 processado
# Exemplo 356/1118658 processado
# Exemplo 357/1118658 processado
# Exemplo 358/1118658 processado
# Exemplo 359/1118658 processado
# Exemplo 360/1118658 processado
# Exemplo 361/1118658 processado
# Exemplo 362/1118658 processado
# Exemplo 363/1118658 processado
# Exemplo 364/1118658 processado
# Exemplo 365/1118658 processado
# Exemplo 366/1118658 processado
# Exemplo 367/1118658 processado
# Exemplo 368/1118658 processado
# Exemplo 369/1118658 processado
# Exemplo 370/1118658 processado
# Exemplo 371/1118658 processado
# Exemplo 372/1118658 processado
# Exemplo 373/1118658 processado
# Exemplo 374/1118658 processado
# Exemplo 375/1118658 processado
# Exemplo 376/1118658 processado
# Exemplo 377/1118658 processado
# Exemplo 378/1118658 processado
# Exemplo 379/1118658 processado
# Exemplo 380/1118658 processado
# Exemplo 381/1118658 processado
# Exemplo 382/1118658 processado
# Exemplo 383/1118658 processado
# Exemplo 384/1118658 processado
# Exemplo 385/1118658 processado
# Exemplo 386/1118658 processado
# Exemplo 387/1118658 processado
# Exemplo 388/1118658 processado
# Exemplo 389/1118658 processado
# Exemplo 390/1118658 processado
# Exemplo 391/1118658 processado
# Exemplo 392/1118658 processado
# Exemplo 393/1118658 processado
# Exemplo 394/1118658 processado
# Exemplo 395/1118658 processado
# Exemplo 396/1118658 processado
# Exemplo 397/1118658 processado
# Exemplo 398/1118658 processado
# Exemplo 399/1118658 processado
# Exemplo 400/1118658 processado
# Exemplo 401/1118658 processado
# Exemplo 402/1118658 processado
# Exemplo 403/1118658 processado
# Exemplo 404/1118658 processado
# Exemplo 405/1118658 processado
# Exemplo 406/1118658 processado
# Exemplo 407/1118658 processado
# Exemplo 408/1118658 processado
# Exemplo 409/1118658 processado
# Exemplo 410/1118658 processado
# Exemplo 411/1118658 processado
# Exemplo 412/1118658 processado
# Exemplo 413/1118658 processado
# Exemplo 414/1118658 processado
# Exemplo 415/1118658 processado
# Exemplo 416/1118658 processado
# Exemplo 417/1118658 processado
# Exemplo 418/1118658 processado
# Exemplo 419/1118658 processado
# Exemplo 420/1118658 processado
# Exemplo 421/1118658 processado
# Exemplo 422/1118658 processado
# Exemplo 423/1118658 processado
# Exemplo 424/1118658 processado
# Exemplo 425/1118658 processado
# Exemplo 426/1118658 processado
# Exemplo 427/1118658 processado
# Exemplo 428/1118658 processado
# Exemplo 429/1118658 processado
# Exemplo 430/1118658 processado
# Exemplo 431/1118658 processado
# Exemplo 432/1118658 processado
# Exemplo 433/1118658 processado
# Exemplo 434/1118658 processado
# Exemplo 435/1118658 processado
# Exemplo 436/1118658 processado
# Exemplo 437/1118658 processado
# Exemplo 438/1118658 processado
# Exemplo 439/1118658 processado
# Exemplo 440/1118658 processado
# Exemplo 441/1118658 processado
# Exemplo 442/1118658 processado
# Exemplo 443/1118658 processado
# Exemplo 444/1118658 processado
# Exemplo 445/1118658 processado
# Exemplo 446/1118658 processado
# Exemplo 447/1118658 processado
# Exemplo 448/1118658 processado
# Exemplo 449/1118658 processado
# Exemplo 450/1118658 processado
# Exemplo 451/1118658 processado
# Exemplo 452/1118658 processado
# Exemplo 453/1118658 processado
# Exemplo 454/1118658 processado
# Exemplo 455/1118658 processado
# Exemplo 456/1118658 processado
# Exemplo 457/1118658 processado
# Exemplo 458/1118658 processado
# Exemplo 459/1118658 processado
# Exemplo 460/1118658 processado
# Exemplo 461/1118658 processado
# Exemplo 462/1118658 processado
# Exemplo 463/1118658 processado
# Exemplo 464/1118658 processado
# Exemplo 465/1118658 processado
# Exemplo 466/1118658 processado
# Exemplo 467/1118658 processado
# Exemplo 468/1118658 processado
# Exemplo 469/1118658 processado
# Exemplo 470/1118658 processado
# Exemplo 471/1118658 processado
# Exemplo 472/1118658 processado
# Exemplo 473/1118658 processado
# Exemplo 474/1118658 processado
# Exemplo 475/1118658 processado
# Exemplo 476/1118658 processado
# Exemplo 477/1118658 processado
# Exemplo 478/1118658 processado
# Exemplo 479/1118658 processado
# Exemplo 480/1118658 processado
# Exemplo 481/1118658 processado
# Exemplo 482/1118658 processado
# Exemplo 483/1118658 processado
# Exemplo 484/1118658 processado
# Exemplo 485/1118658 processado
# Exemplo 486/1118658 processado
# Exemplo 487/1118658 processado
# Exemplo 488/1118658 processado
# Exemplo 489/1118658 processado
# Exemplo 490/1118658 processado
# Exemplo 491/1118658 processado
# Exemplo 492/1118658 processado
# Exemplo 493/1118658 processado
# Exemplo 494/1118658 processado
# Exemplo 495/1118658 processado
# Exemplo 496/1118658 processado
# Exemplo 497/1118658 processado
# Exemplo 498/1118658 processado
# Exemplo 499/1118658 processado
# Exemplo 500/1118658 processado
# Exemplo 501/1118658 processado
# Exemplo 502/1118658 processado
# Exemplo 503/1118658 processado
# Exemplo 504/1118658 processado
# Exemplo 505/1118658 processado
# Exemplo 506/1118658 processado
# Exemplo 507/1118658 processado
# Exemplo 508/1118658 processado
# Exemplo 509/1118658 processado
# Exemplo 510/1118658 processado
# Exemplo 511/1118658 processado
# Exemplo 512/1118658 processado
# Exemplo 513/1118658 processado
# Exemplo 514/1118658 processado
# Exemplo 515/1118658 processado
# Exemplo 516/1118658 processado
# Exemplo 517/1118658 processado
# Exemplo 518/1118658 processado
# Exemplo 519/1118658 processado
# Exemplo 520/1118658 processado
# Exemplo 521/1118658 processado
# Exemplo 522/1118658 processado
# Exemplo 523/1118658 processado
# Exemplo 524/1118658 processado
# Exemplo 525/1118658 processado
# Exemplo 526/1118658 processado
# Exemplo 527/1118658 processado
# Exemplo 528/1118658 processado
# Exemplo 529/1118658 processado
# Exemplo 530/1118658 processado
# Exemplo 531/1118658 processado
# Exemplo 532/1118658 processado
# Exemplo 533/1118658 processado
# Exemplo 534/1118658 processado
# Exemplo 535/1118658 processado
# Exemplo 536/1118658 processado
# Exemplo 537/1118658 processado
# Exemplo 538/1118658 processado
# Exemplo 539/1118658 processado
# Exemplo 540/1118658 processado
# Exemplo 541/1118658 processado
# Exemplo 542/1118658 processado
# Exemplo 543/1118658 processado
# Exemplo 544/1118658 processado
# Exemplo 545/1118658 processado
# Exemplo 546/1118658 processado
# Exemplo 547/1118658 processado
# Exemplo 548/1118658 processado
# Exemplo 549/1118658 processado
# Exemplo 550/1118658 processado
# Exemplo 551/1118658 processado
# Exemplo 552/1118658 processado
# Exemplo 553/1118658 processado
# Exemplo 554/1118658 processado
# Exemplo 555/1118658 processado
# Exemplo 556/1118658 processado
# Exemplo 557/1118658 processado
# Exemplo 558/1118658 processado
# Exemplo 559/1118658 processado
# Exemplo 560/1118658 processado
# Exemplo 561/1118658 processado
# Exemplo 562/1118658 processado
# Exemplo 563/1118658 processado
# Exemplo 564/1118658 processado
# Exemplo 565/1118658 processado
# Exemplo 566/1118658 processado
# Exemplo 567/1118658 processado
# Exemplo 568/1118658 processado
# Exemplo 569/1118658 processado
# Exemplo 570/1118658 processado
# Exemplo 571/1118658 processado
# Exemplo 572/1118658 processado
# Exemplo 573/1118658 processado
# Exemplo 574/1118658 processado
# Exemplo 575/1118658 processado
# Exemplo 576/1118658 processado
# Exemplo 577/1118658 processado
# Exemplo 578/1118658 processado
# Exemplo 579/1118658 processado
# Exemplo 580/1118658 processado
# Exemplo 581/1118658 processado
# Exemplo 582/1118658 processado
# Exemplo 583/1118658 processado
# Exemplo 584/1118658 processado
# Exemplo 585/1118658 processado
# Exemplo 586/1118658 processado
# Exemplo 587/1118658 processado
# Exemplo 588/1118658 processado
# Exemplo 589/1118658 processado
# Exemplo 590/1118658 processado
# Exemplo 591/1118658 processado
# Exemplo 592/1118658 processado
# Exemplo 593/1118658 processado
# Exemplo 594/1118658 processado
# Exemplo 595/1118658 processado
# Exemplo 596/1118658 processado
# Exemplo 597/1118658 processado
# Exemplo 598/1118658 processado
# Exemplo 599/1118658 processado
# Exemplo 600/1118658 processado
# Exemplo 601/1118658 processado
# Exemplo 602/1118658 processado
# Exemplo 603/1118658 processado
# Exemplo 604/1118658 processado
# Exemplo 605/1118658 processado
# Exemplo 606/1118658 processado
# Exemplo 607/1118658 processado
# Exemplo 608/1118658 processado
# Exemplo 609/1118658 processado
# Exemplo 610/1118658 processado
# Exemplo 611/1118658 processado
# Exemplo 612/1118658 processado
# Exemplo 613/1118658 processado
# Exemplo 614/1118658 processado
# Exemplo 615/1118658 processado
# Exemplo 616/1118658 processado
# Exemplo 617/1118658 processado
# Exemplo 618/1118658 processado
# Exemplo 619/1118658 processado
# Exemplo 620/1118658 processado
# Exemplo 621/1118658 processado
# Exemplo 622/1118658 processado
# Exemplo 623/1118658 processado
# Exemplo 624/1118658 processado
# Exemplo 625/1118658 processado
# Exemplo 626/1118658 processado
# Exemplo 627/1118658 processado
# Exemplo 628/1118658 processado
# Exemplo 629/1118658 processado
# Exemplo 630/1118658 processado
# Exemplo 631/1118658 processado
# Exemplo 632/1118658 processado
# Exemplo 633/1118658 processado
# Exemplo 634/1118658 processado
# Exemplo 635/1118658 processado
# Exemplo 636/1118658 processado
# Exemplo 637/1118658 processado
# Exemplo 638/1118658 processado
# Exemplo 639/1118658 processado
# Exemplo 640/1118658 processado
# Exemplo 641/1118658 processado
# Exemplo 642/1118658 processado
# Exemplo 643/1118658 processado
# Exemplo 644/1118658 processado
# Exemplo 645/1118658 processado
# Exemplo 646/1118658 processado
# Exemplo 647/1118658 processado
# Exemplo 648/1118658 processado
# Exemplo 649/1118658 processado
# Exemplo 650/1118658 processado
# Exemplo 651/1118658 processado
# Exemplo 652/1118658 processado
# Exemplo 653/1118658 processado
# Exemplo 654/1118658 processado
# Exemplo 655/1118658 processado
# Exemplo 656/1118658 processado
# Exemplo 657/1118658 processado
# Exemplo 658/1118658 processado
# Exemplo 659/1118658 processado
# Exemplo 660/1118658 processado
# Exemplo 661/1118658 processado
# Exemplo 662/1118658 processado
# Exemplo 663/1118658 processado
# Exemplo 664/1118658 processado
# Exemplo 665/1118658 processado
# Exemplo 666/1118658 processado
# Exemplo 667/1118658 processado
# Exemplo 668/1118658 processado
# Exemplo 669/1118658 processado
# Exemplo 670/1118658 processado
# Exemplo 671/1118658 processado
# Exemplo 672/1118658 processado
# Exemplo 673/1118658 processado
# Exemplo 674/1118658 processado
# Exemplo 675/1118658 processado
# Exemplo 676/1118658 processado
# Exemplo 677/1118658 processado
# Exemplo 678/1118658 processado
# Exemplo 679/1118658 processado
# Exemplo 680/1118658 processado
# Exemplo 681/1118658 processado
# Exemplo 682/1118658 processado
# Exemplo 683/1118658 processado
# Exemplo 684/1118658 processado
# Exemplo 685/1118658 processado
# Exemplo 686/1118658 processado
# Exemplo 687/1118658 processado
# Exemplo 688/1118658 processado
# Exemplo 689/1118658 processado
# Exemplo 690/1118658 processado
# Exemplo 691/1118658 processado
# Exemplo 692/1118658 processado
# Exemplo 693/1118658 processado
# Exemplo 694/1118658 processado
# Exemplo 695/1118658 processado
# Exemplo 696/1118658 processado
# Exemplo 697/1118658 processado
# Exemplo 698/1118658 processado
# Exemplo 699/1118658 processado
# Exemplo 700/1118658 processado
# Exemplo 701/1118658 processado
# Exemplo 702/1118658 processado
# Exemplo 703/1118658 processado
# Exemplo 704/1118658 processado
# Exemplo 705/1118658 processado
# Exemplo 706/1118658 processado
# Exemplo 707/1118658 processado
# Exemplo 708/1118658 processado
# Exemplo 709/1118658 processado
# Exemplo 710/1118658 processado
# Exemplo 711/1118658 processado
# Exemplo 712/1118658 processado
# Exemplo 713/1118658 processado
# Exemplo 714/1118658 processado
# Exemplo 715/1118658 processado
# Exemplo 716/1118658 processado
# Exemplo 717/1118658 processado
# Exemplo 718/1118658 processado
# Exemplo 719/1118658 processado
# Exemplo 720/1118658 processado
# Exemplo 721/1118658 processado
# Exemplo 722/1118658 processado
# Exemplo 723/1118658 processado
# Exemplo 724/1118658 processado
# Exemplo 725/1118658 processado
# Exemplo 726/1118658 processado
# Exemplo 727/1118658 processado
# Exemplo 728/1118658 processado
# Exemplo 729/1118658 processado
# Exemplo 730/1118658 processado
# Exemplo 731/1118658 processado
# Exemplo 732/1118658 processado
# Exemplo 733/1118658 processado
# Exemplo 734/1118658 processado
# Exemplo 735/1118658 processado
# Exemplo 736/1118658 processado
# Exemplo 737/1118658 processado
# Exemplo 738/1118658 processado
# Exemplo 739/1118658 processado
# Exemplo 740/1118658 processado
# Exemplo 741/1118658 processado
# Exemplo 742/1118658 processado
# Exemplo 743/1118658 processado
# Exemplo 744/1118658 processado
# Exemplo 745/1118658 processado
# Exemplo 746/1118658 processado
# Exemplo 747/1118658 processado
# Exemplo 748/1118658 processado
# Exemplo 749/1118658 processado
# Exemplo 750/1118658 processado
# Exemplo 751/1118658 processado
# Exemplo 752/1118658 processado
# Exemplo 753/1118658 processado
# Exemplo 754/1118658 processado
# Exemplo 755/1118658 processado
# Exemplo 756/1118658 processado
# Exemplo 757/1118658 processado
# Exemplo 758/1118658 processado
# Exemplo 759/1118658 processado
# Exemplo 760/1118658 processado
# Exemplo 761/1118658 processado
# Exemplo 762/1118658 processado
# Exemplo 763/1118658 processado
# Exemplo 764/1118658 processado
# Exemplo 765/1118658 processado
# Exemplo 766/1118658 processado
# Exemplo 767/1118658 processado
# Exemplo 768/1118658 processado
# Exemplo 769/1118658 processado
# Exemplo 770/1118658 processado
# Exemplo 771/1118658 processado
# Exemplo 772/1118658 processado
# Exemplo 773/1118658 processado
# Exemplo 774/1118658 processado
# Exemplo 775/1118658 processado
# Exemplo 776/1118658 processado
# Exemplo 777/1118658 processado
# Exemplo 778/1118658 processado
# Exemplo 779/1118658 processado
# Exemplo 780/1118658 processado
# Exemplo 781/1118658 processado
# Exemplo 782/1118658 processado
# Exemplo 783/1118658 processado
# Exemplo 784/1118658 processado
# Exemplo 785/1118658 processado
# Exemplo 786/1118658 processado
# Exemplo 787/1118658 processado
# Exemplo 788/1118658 processado
# Exemplo 789/1118658 processado
# Exemplo 790/1118658 processado
# Exemplo 791/1118658 processado
# Exemplo 792/1118658 processado
# Exemplo 793/1118658 processado
# Exemplo 794/1118658 processado
# Exemplo 795/1118658 processado
# Exemplo 796/1118658 processado
# Exemplo 797/1118658 processado
# Exemplo 798/1118658 processado
# Exemplo 799/1118658 processado
# Exemplo 800/1118658 processado
# Exemplo 801/1118658 processado
# Exemplo 802/1118658 processado
# Exemplo 803/1118658 processado
# Exemplo 804/1118658 processado
# Exemplo 805/1118658 processado
# Exemplo 806/1118658 processado
# Exemplo 807/1118658 processado
# Exemplo 808/1118658 processado
# Exemplo 809/1118658 processado
# Exemplo 810/1118658 processado
# Exemplo 811/1118658 processado
# Exemplo 812/1118658 processado
# Exemplo 813/1118658 processado
# Exemplo 814/1118658 processado
# Exemplo 815/1118658 processado
# Exemplo 816/1118658 processado
# Exemplo 817/1118658 processado
# Exemplo 818/1118658 processado
# Exemplo 819/1118658 processado
# Exemplo 820/1118658 processado
# Exemplo 821/1118658 processado
# Exemplo 822/1118658 processado
# Exemplo 823/1118658 processado
# Exemplo 824/1118658 processado
# Exemplo 825/1118658 processado
# Exemplo 826/1118658 processado
# Exemplo 827/1118658 processado
# Exemplo 828/1118658 processado
# Exemplo 829/1118658 processado
# Exemplo 830/1118658 processado
# Exemplo 831/1118658 processado
# Exemplo 832/1118658 processado
# Exemplo 833/1118658 processado
# Exemplo 834/1118658 processado
# Exemplo 835/1118658 processado
# Exemplo 836/1118658 processado
# Exemplo 837/1118658 processado
# Exemplo 838/1118658 processado
# Exemplo 839/1118658 processado
# Exemplo 840/1118658 processado
# Exemplo 841/1118658 processado
# Exemplo 842/1118658 processado
# Exemplo 843/1118658 processado
# Exemplo 844/1118658 processado
# Exemplo 845/1118658 processado
# Exemplo 846/1118658 processado
# Exemplo 847/1118658 processado
# Exemplo 848/1118658 processado
# Exemplo 849/1118658 processado
# Exemplo 850/1118658 processado
# Exemplo 851/1118658 processado
# Exemplo 852/1118658 processado
# Exemplo 853/1118658 processado
# Exemplo 854/1118658 processado
# Exemplo 855/1118658 processado
# Exemplo 856/1118658 processado
# Exemplo 857/1118658 processado
# Exemplo 858/1118658 processado
# Exemplo 859/1118658 processado
# Exemplo 860/1118658 processado
# Exemplo 861/1118658 processado
# Exemplo 862/1118658 processado
# Exemplo 863/1118658 processado
# Exemplo 864/1118658 processado
# Exemplo 865/1118658 processado
# Exemplo 866/1118658 processado
# Exemplo 867/1118658 processado
# Exemplo 868/1118658 processado
# Exemplo 869/1118658 processado
# Exemplo 870/1118658 processado
# Exemplo 871/1118658 processado
# Exemplo 872/1118658 processado
# Exemplo 873/1118658 processado
# Exemplo 874/1118658 processado
# Exemplo 875/1118658 processado
# Exemplo 876/1118658 processado
# Exemplo 877/1118658 processado
# Exemplo 878/1118658 processado
# Exemplo 879/1118658 processado
# Exemplo 880/1118658 processado
# Exemplo 881/1118658 processado
# Exemplo 882/1118658 processado
# Exemplo 883/1118658 processado
# Exemplo 884/1118658 processado
# Exemplo 885/1118658 processado
# Exemplo 886/1118658 processado
# Exemplo 887/1118658 processado
# Exemplo 888/1118658 processado
# Exemplo 889/1118658 processado
# Exemplo 890/1118658 processado
# Exemplo 891/1118658 processado
# Exemplo 892/1118658 processado
# Exemplo 893/1118658 processado
# Exemplo 894/1118658 processado
# Exemplo 895/1118658 processado
# Exemplo 896/1118658 processado
# Exemplo 897/1118658 processado
# Exemplo 898/1118658 processado
# Exemplo 899/1118658 processado
# Exemplo 900/1118658 processado
# Exemplo 901/1118658 processado
# Exemplo 902/1118658 processado
# Exemplo 903/1118658 processado
# Exemplo 904/1118658 processado
# Exemplo 905/1118658 processado
# Exemplo 906/1118658 processado
# Exemplo 907/1118658 processado
# Exemplo 908/1118658 processado
# Exemplo 909/1118658 processado
# Exemplo 910/1118658 processado
# Exemplo 911/1118658 processado
# Exemplo 912/1118658 processado
# Exemplo 913/1118658 processado
# Exemplo 914/1118658 processado
# Exemplo 915/1118658 processado
# Exemplo 916/1118658 processado
# Exemplo 917/1118658 processado
# Exemplo 918/1118658 processado
# Exemplo 919/1118658 processado
# Exemplo 920/1118658 processado
# Exemplo 921/1118658 processado
# Exemplo 922/1118658 processado
# Exemplo 923/1118658 processado
# Exemplo 924/1118658 processado
# Exemplo 925/1118658 processado
# Exemplo 926/1118658 processado
# Exemplo 927/1118658 processado
# Exemplo 928/1118658 processado
# Exemplo 929/1118658 processado
# Exemplo 930/1118658 processado
# Exemplo 931/1118658 processado
# Exemplo 932/1118658 processado
# Exemplo 933/1118658 processado
# Exemplo 934/1118658 processado
# Exemplo 935/1118658 processado
# Exemplo 936/1118658 processado
# Exemplo 937/1118658 processado
# Exemplo 938/1118658 processado
# Exemplo 939/1118658 processado
# Exemplo 940/1118658 processado
# Exemplo 941/1118658 processado
# Exemplo 942/1118658 processado
# Exemplo 943/1118658 processado
# Exemplo 944/1118658 processado
# Exemplo 945/1118658 processado
# Exemplo 946/1118658 processado
# Exemplo 947/1118658 processado
# Exemplo 948/1118658 processado
# Exemplo 949/1118658 processado
# Exemplo 950/1118658 processado
# Exemplo 951/1118658 processado
# Exemplo 952/1118658 processado
# Exemplo 953/1118658 processado
# Exemplo 954/1118658 processado
# Exemplo 955/1118658 processado
# Exemplo 956/1118658 processado
# Exemplo 957/1118658 processado
# Exemplo 958/1118658 processado
# Exemplo 959/1118658 processado
# Exemplo 960/1118658 processado
# Exemplo 961/1118658 processado
# Exemplo 962/1118658 processado
# Exemplo 963/1118658 processado
# Exemplo 964/1118658 processado
# Exemplo 965/1118658 processado
# Exemplo 966/1118658 processado
# Exemplo 967/1118658 processado
# Exemplo 968/1118658 processado
# Exemplo 969/1118658 processado
# Exemplo 970/1118658 processado
# Exemplo 971/1118658 processado
# Exemplo 972/1118658 processado
# Exemplo 973/1118658 processado
# Exemplo 974/1118658 processado
# Exemplo 975/1118658 processado
# Exemplo 976/1118658 processado
# Exemplo 977/1118658 processado
# Exemplo 978/1118658 processado
# Exemplo 979/1118658 processado
# Exemplo 980/1118658 processado
# Exemplo 981/1118658 processado
# Exemplo 982/1118658 processado
# Exemplo 983/1118658 processado
# Exemplo 984/1118658 processado
# Exemplo 985/1118658 processado
# Exemplo 986/1118658 processado
# Exemplo 987/1118658 processado
# Exemplo 988/1118658 processado
# Exemplo 989/1118658 processado
# Exemplo 990/1118658 processado
# Exemplo 991/1118658 processado
# Exemplo 992/1118658 processado
# Exemplo 993/1118658 processado
# Exemplo 994/1118658 processado
# Exemplo 995/1118658 processado
# Exemplo 996/1118658 processado
# Exemplo 997/1118658 processado
# Exemplo 998/1118658 processado
# Exemplo 999/1118658 processado
# Exemplo 1000/1118658 processado
# Exemplo 1001/1118658 processado
# Exemplo 1002/1118658 processado
# Exemplo 1003/1118658 processado
# Exemplo 1004/1118658 processado
# Exemplo 1005/1118658 processado
# Exemplo 1006/1118658 processado
# Exemplo 1007/1118658 processado
# Exemplo 1008/1118658 processado
# Exemplo 1009/1118658 processado
# Exemplo 1010/1118658 processado
# Exemplo 1011/1118658 processado
# Exemplo 1012/1118658 processado
# Exemplo 1013/1118658 processado
# Exemplo 1014/1118658 processado
# Exemplo 1015/1118658 processado
# Exemplo 1016/1118658 processado
# Exemplo 1017/1118658 processado
# Exemplo 1018/1118658 processado
# Exemplo 1019/1118658 processado
# Exemplo 1020/1118658 processado
# Exemplo 1021/1118658 processado
# Exemplo 1022/1118658 processado
# Exemplo 1023/1118658 processado
# Exemplo 1024/1118658 processado
# Exemplo 1025/1118658 processado
# Exemplo 1026/1118658 processado
# Exemplo 1027/1118658 processado
# Exemplo 1028/1118658 processado
# Exemplo 1029/1118658 processado
# Exemplo 1030/1118658 processado
# Exemplo 1031/1118658 processado
# Exemplo 1032/1118658 processado
# Exemplo 1033/1118658 processado
# Exemplo 1034/1118658 processado
# Exemplo 1035/1118658 processado
# Exemplo 1036/1118658 processado
# Exemplo 1037/1118658 processado
# Exemplo 1038/1118658 processado
# Exemplo 1039/1118658 processado
# Exemplo 1040/1118658 processado
# Exemplo 1041/1118658 processado
# Exemplo 1042/1118658 processado
# Exemplo 1043/1118658 processado
# Exemplo 1044/1118658 processado
# Exemplo 1045/1118658 processado
# Exemplo 1046/1118658 processado
# Exemplo 1047/1118658 processado
# Exemplo 1048/1118658 processado
# Exemplo 1049/1118658 processado
# Exemplo 1050/1118658 processado
# Exemplo 1051/1118658 processado
# Exemplo 1052/1118658 processado
# Exemplo 1053/1118658 processado
# Exemplo 1054/1118658 processado
# Exemplo 1055/1118658 processado
# Exemplo 1056/1118658 processado
# Exemplo 1057/1118658 processado
# Exemplo 1058/1118658 processado
# Exemplo 1059/1118658 processado
# Exemplo 1060/1118658 processado
# Exemplo 1061/1118658 processado
# Exemplo 1062/1118658 processado
# Exemplo 1063/1118658 processado
# Exemplo 1064/1118658 processado
# Exemplo 1065/1118658 processado
# Exemplo 1066/1118658 processado
# Exemplo 1067/1118658 processado
# Exemplo 1068/1118658 processado
# Exemplo 1069/1118658 processado
# Exemplo 1070/1118658 processado
# Exemplo 1071/1118658 processado
# Exemplo 1072/1118658 processado
# Exemplo 1073/1118658 processado
# Exemplo 1074/1118658 processado
# Exemplo 1075/1118658 processado
# Exemplo 1076/1118658 processado
# Exemplo 1077/1118658 processado
# Exemplo 1078/1118658 processado
# Exemplo 1079/1118658 processado
# Exemplo 1080/1118658 processado
# Exemplo 1081/1118658 processado
# Exemplo 1082/1118658 processado
# Exemplo 1083/1118658 processado
# Exemplo 1084/1118658 processado
# Exemplo 1085/1118658 processado
# Exemplo 1086/1118658 processado
# Exemplo 1087/1118658 processado
# Exemplo 1088/1118658 processado
# Exemplo 1089/1118658 processado
# Exemplo 1090/1118658 processado
# Exemplo 1091/1118658 processado
# Exemplo 1092/1118658 processado
# Exemplo 1093/1118658 processado
# Exemplo 1094/1118658 processado
# Exemplo 1095/1118658 processado
# Exemplo 1096/1118658 processado
# Exemplo 1097/1118658 processado
# Exemplo 1098/1118658 processado
# Exemplo 1099/1118658 processado
# Exemplo 1100/1118658 processado
# Exemplo 1101/1118658 processado
# Exemplo 1102/1118658 processado
# Exemplo 1103/1118658 processado
# Exemplo 1104/1118658 processado
# Exemplo 1105/1118658 processado
# Exemplo 1106/1118658 processado
# Exemplo 1107/1118658 processado
# Exemplo 1108/1118658 processado
# Exemplo 1109/1118658 processado
# Exemplo 1110/1118658 processado
# Exemplo 1111/1118658 processado
# Exemplo 1112/1118658 processado
# Exemplo 1113/1118658 processado
# Exemplo 1114/1118658 processado
# Exemplo 1115/1118658 processado
# Exemplo 1116/1118658 processado
# Exemplo 1117/1118658 processado
# Exemplo 1118/1118658 processado
# Exemplo 1119/1118658 processado
# Exemplo 1120/1118658 processado
# Exemplo 1121/1118658 processado
# Exemplo 1122/1118658 processado
# Exemplo 1123/1118658 processado
# Exemplo 1124/1118658 processado
# Exemplo 1125/1118658 processado
# Exemplo 1126/1118658 processado
# Exemplo 1127/1118658 processado
# Exemplo 1128/1118658 processado
# Exemplo 1129/1118658 processado
# Exemplo 1130/1118658 processado
# Exemplo 1131/1118658 processado
# Exemplo 1132/1118658 processado
# Exemplo 1133/1118658 processado
# Exemplo 1134/1118658 processado
# Exemplo 1135/1118658 processado
# Exemplo 1136/1118658 processado
# Exemplo 1137/1118658 processado
# Exemplo 1138/1118658 processado
# Exemplo 1139/1118658 processado
# Exemplo 1140/1118658 processado
# Exemplo 1141/1118658 processado
# Exemplo 1142/1118658 processado
# Exemplo 1143/1118658 processado
# Exemplo 1144/1118658 processado
# Exemplo 1145/1118658 processado
# Exemplo 1146/1118658 processado
# Exemplo 1147/1118658 processado
# Exemplo 1148/1118658 processado
# Exemplo 1149/1118658 processado
# Exemplo 1150/1118658 processado
# Exemplo 1151/1118658 processado
# Exemplo 1152/1118658 processado
# Exemplo 1153/1118658 processado
# Exemplo 1154/1118658 processado
# Exemplo 1155/1118658 processado
# Exemplo 1156/1118658 processado
# Exemplo 1157/1118658 processado
# Exemplo 1158/1118658 processado
# Exemplo 1159/1118658 processado
# Exemplo 1160/1118658 processado
# Exemplo 1161/1118658 processado
# Exemplo 1162/1118658 processado
# Exemplo 1163/1118658 processado
# Exemplo 1164/1118658 processado
# Exemplo 1165/1118658 processado
# Exemplo 1166/1118658 processado
# Exemplo 1167/1118658 processado
# Exemplo 1168/1118658 processado
# Exemplo 1169/1118658 processado
# Exemplo 1170/1118658 processado
# Exemplo 1171/1118658 processado
# Exemplo 1172/1118658 processado
# Exemplo 1173/1118658 processado
# Exemplo 1174/1118658 processado
# Exemplo 1175/1118658 processado
# Exemplo 1176/1118658 processado
# Exemplo 1177/1118658 processado
# Exemplo 1178/1118658 processado
# Exemplo 1179/1118658 processado
# Exemplo 1180/1118658 processado
# Exemplo 1181/1118658 processado
# Exemplo 1182/1118658 processado
# Exemplo 1183/1118658 processado
# Exemplo 1184/1118658 processado
# Exemplo 1185/1118658 processado
# Exemplo 1186/1118658 processado
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb Cell 24 line 4
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=40'>41</a>     def forward(self, pooled_output):
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=41'>42</a>         return self.classifier(pooled_output)
# ---> <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=43'>44</a> classifier = CustomClassifier()
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=44'>45</a> outputs = classifier(pooler_output)
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=46'>47</a> # Obter a classe prevista
#
# /home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb Cell 24 line 3
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=36'>37</a> super(CustomClassifier, self).__init__()
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=37'>38</a> self.num_classes = 5  # Defina o número correto de classes aqui
# ---> <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#Y214sZmlsZQ%3D%3D?line=38'>39</a> self.classifier = torch.nn.Linear(model.config.hidden_size, self.num_classes).to('cuda')
#
# File ~/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:989, in Module.to(self, *args, **kwargs)
#     985         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     986                     non_blocking, memory_format=convert_to_format)
#     987     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# --> 989 return self._apply(convert)
#
# File ~/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:664, in Module._apply(self, fn)
#     660 # Tensors stored in modules are graph leaves, and we don't want to
#     661 # track autograd history of `param_applied`, so we have to use
#     662 # `with torch.no_grad():`
#     663 with torch.no_grad():
# --> 664     param_applied = fn(param)
#     665 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     666 if should_use_set_data:
#
# File ~/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:987, in Module.to.<locals>.convert(t)
#     984 if convert_to_format is not None and t.dim() in (4, 5):
#     985     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     986                 non_blocking, memory_format=convert_to_format)
# --> 987 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# KeyboardInterrupt:

# %%
predicted_categories
# Out:
# ['Clothing',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Clothing',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Clothing',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Food',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Clothing',
#  'Food',
#  'Food',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Clothing',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Clothing',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Food',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Clothing',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Clothing',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Clothing',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Clothing',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Food',
#  'Clothing',
#  'Clothing',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Clothing',
#  'Home and Kitchen',
#  'Home and Kitchen',
#  'Food',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Clothing',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Clothing',
#  'Food',
#  'Clothing',
#  'Food',
#  'Clothing',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Clothing',
#  'Food',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Clothing',
#  'Electronics, Computers',
#  'Clothing',
#  'Clothing',
#  'Home and Kitchen',
#  'Food',
#  'Clothing',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Home and Kitchen',
#  'Clothing',
#  'Clothing',
#  'Food',
#  'Health, Beauty',
#  'Home and Kitchen',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  ...]

# %%
# # Verifique se uma GPU está disponível
# if torch.cuda.is_available():
#     # Mova o modelo para a GPU
#     model.to('cuda')
    
#     # Criar uma lista para armazenar as previsões
#     predictions = []
#     categories = {
#                 0: "Food",
#                 1: "Automotive",
#                 2: "Health, Beauty",
#                 3: "Electronics, Computers",
#                 4: "Arts, Crafts",
#                 5: "Home and Kitchen",
#                 6: "Clothing and Accessories",
#                 7: "Sports",
#                 8: "Office",
#                 9: "Movies, Music",
#                 10: "Books"     
#             }
    
#     # Iterar sobre todos os exemplos no seu conjunto de dados
#     for example in dataset:
#         title = example["title"]

#         # Montar o prompt de classificação de texto
#         prompt = f"Classify the following product title into its category:\n\n{title}\n\nCandidate categories: {list(categories.values())}."

#         # Tokenizar o prompt e codificá-lo para uso com o modelo
#         inputs = tokenizer(prompt, return_tensors="pt").to('cuda')  # Mova os inputs para a GPU
        
#         # Obter o pooler_output após a passagem pelo modelo
#         with torch.no_grad():
#             model_outputs = model(**inputs)
#             pooler_output = model_outputs.pooler_output

#         # Adicionar uma camada de classificação personalizada
#         class CustomClassifier(torch.nn.Module):
#             def __init__(self):
#                 super(CustomClassifier, self).__init__()
#                 self.num_classes = len(categories)  # Defina o número correto de classes aqui
#                 self.classifier = torch.nn.Linear(model.config.hidden_size, self.num_classes).to('cuda')  # Mova o classificador para a GPU

#             def forward(self, pooled_output):
#                 return self.classifier(pooled_output)
        
#         classifier = CustomClassifier()
#         outputs = classifier(pooler_output)

#         # Obter a classe prevista
#         predicted_class = torch.argmax(outputs, dim=1).item()

#         # Armazenar a previsão na lista de previsões
#         predictions.append(predicted_class)
#         predicted_categories = [categories[index] for index in predictions]
#         print(f"Exemplo {i + 1}/{len(dataset)} processado")
# else:
#     print("GPU não disponível. Usando CPU.")

# %%
predicted_categories
# Out:
# ['Automotive',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Food',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Arts, Crafts',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Food',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Food',
#  'Food',
#  'Food',
#  'Automotive',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Automotive',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Food',
#  'Automotive',
#  'Food',
#  'Food',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Automotive',
#  'Arts, Crafts',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Automotive',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Automotive',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Automotive',
#  'Arts, Crafts',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Arts, Crafts',
#  'Food',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Food',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Food',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Automotive',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Automotive',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Arts, Crafts',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Food',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Automotive',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Arts, Crafts',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Automotive',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Arts, Crafts',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Automotive',
#  'Automotive',
#  'Automotive',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Food',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Arts, Crafts',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Food',
#  'Food',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Automotive',
#  'Automotive',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Automotive',
#  'Automotive',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Food',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Automotive',
#  'Health, Beauty',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Arts, Crafts',
#  'Automotive',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Food',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Food',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Food',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Arts, Crafts',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Health, Beauty',
#  'Automotive',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Food',
#  'Health, Beauty',
#  'Automotive',
#  'Health, Beauty',
#  'Food',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Automotive',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Food',
#  'Automotive',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Automotive',
#  'Arts, Crafts',
#  'Automotive',
#  'Food',
#  'Arts, Crafts',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Health, Beauty',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  'Electronics, Computers',
#  'Arts, Crafts',
#  'Arts, Crafts',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Automotive',
#  'Food',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Health, Beauty',
#  'Electronics, Computers',
#  'Electronics, Computers',
#  'Food',
#  'Food',
#  'Arts, Crafts',
#  ...]

# %%
len(predicted_categories)
# Out:
# 549984

# %%
df_original = dataset.to_pandas().head()
# Out:
#            docid                                              title  \
# 0              1  FYY Leather Case with Mirror for Samsung Galax...
# 1              2  Playtex Women's 18 Hour Easy On, Easy Off Fron...
# 2              4  YUEPIN U-Tube Clamp 304 Stainless Steel Hose P...
# 3              5            Bruce's Big Storm (Mother Bruce Series)
# 4              6  DJI Shoulder Neck Strap Belt Sling Lanyard Nec...
# ...          ...                                                ...
# 1118653  1661902  SMARTSTANDARD 10ft Heavy Duty Double Door Slid...
# 1118654  1661903        Men's DMC V Cosplay Costume Full Set Outfit
# 1118655  1661905  OYATON Christmas Votive Candle Holders with Sn...
# 1118656  1661906  BirdRock Home 5 Gallon Stainless Steel Beverag...
# 1118657  1661907  Degree Men Antiperspirant Deodorant Adventure ...
#
#                                                       text
# 0        Product Description Premium PU Leather Top qua...
# 1        Product Description Introducing Playtex 18 hou...
# 2        Product Description Specification: Material: 3...
# 3
# 4        Product Description Specifications: Item Condi...
# ...                                                    ...
# 1118653  From the brand Previous page SmartStandard is ...
# 1118654  Product Description Size Chart: X-Small: Heigh...
# 1118655  From the brand Christmas holiday decorations F...
# 1118656  From the brand Previous page Holiday Home Deco...
# 1118657  Product Description Degree is upgrading to our...
#
# [1118658 rows x 3 columns]

# %%
# Criar um DataFrame a partir da lista de previsões
data = {'Predicted_Category': predicted_categories}
df = pd.DataFrame(data)

# %%
df['Predicted_Category'].value_counts()
# Out:
# Predicted_Category
# Automotive                110392
# Arts, Crafts              110202
# Food                      109888
# Electronics, Computers    109772
# Health, Beauty            109730
# Name: count, dtype: int64

# %%
# Salvar o DataFrame em um arquivo CSV
df.to_parquet('categories.parquet', index=False, compression="gzip")

# %%
# Criar um DataFrame a partir da lista de previsões
data = {'Predicted_Category': predicted_categories}
df = pd.DataFrame(data)

# Salvar o DataFrame em um arquivo CSV
df.to_parquet('categories.parquet', index=False, compression="gzip")

# %% [markdown]
# predicted_category

# %%
dataset_prompt_eng = dataset.select(range(50))

# %%
for i in range(50):
    print(dataset_prompt_eng[i]["title"])
    print()
# Out:
# FYY Leather Case with Mirror for Samsung Galaxy S8 Plus, Leather Wallet Flip Folio Case with Mirror and Wrist Strap for Samsung Galaxy S8 Plus Black
#
# Playtex Women's 18 Hour Easy On, Easy Off Front & Back Close Post Surgery Bra US400C
#
# YUEPIN U-Tube Clamp 304 Stainless Steel Hose Pipe Cable Strap Clips With Rubber Cushioned (1-21/32"(42mm)-10pcs)
#
# Bruce's Big Storm (Mother Bruce Series)
#
# DJI Shoulder Neck Strap Belt Sling Lanyard Necklaces for Dji Phantom 3 Inspire 1 Remote
#
# Crocs Jibbitz 5-Pack Alien Shoe Charms | Jibbitz for Crocs
#
# Design Toscano QM2787100 Darby, the Forest Fawn Baby Deer Statue,full color
#
# Zeagoo Women's Open Front Cardigan 3/4 Sleeve Draped Ruffles Soft Knit Sweaters
#
# Rekayla Open Toe Tie Up Ankle Wrap Flat Sandals for Women
#
# Apron for Women, Waterproof Adjustable Bib Cooking Aprons with Pocket-2 Side Coral Velvet Towels Stitched Durable Pinstripe Aprons for Dishwashing, Baking, Grill, Restaurant Even Garden Craft
#
# DIY 5D Diamond Painting by Number Kit for Adult, Full Drill Crystal Rhinestone Embroidery Cross Stitch Diamond Embroidery Dotz Kit Home Wall Decor 15.8×11.8 Inch (Wolf)
#
# Under Armour Men's Micro G Pursuit-Wide Sneaker, 15
#
# Drake Feelings MyFaveGift Drizzy Champagne Papi If You're Reading This You're Too Close 11oz Coffee Mug Cup Gifts For Drake Lover
#
# Spider-Man: Homecoming Spider Sight Mask
#
# Tee Luv ICEE Polar Bear Logo T-Shirt
#
# GADIEMKENSD Unisex Baseball Cap Breathable Sport Hat
#
# dbest products Trolley Dolly Red Foldable Shopping cart for Groceries with Wheels and Removable Bag and Rolling Personal Handtruck Standard
#
# Pure Daily Care Luma - 4 in 1 Skin Therapy Wand - Ion Therapy LED Light Machine - Wave Stimulation- Massage - Anti Aging - Lift & Firm Tighten Skin Wrinkles
#
# Engraved Desk Name Plate for Home Office - Beautiful Custom Desk Name Plate for Business Professional & Office Staff
#
# H2H Mens Casual Slim Fit Turtleneck Pullover Knit Lightweight Sweaters Shirts
#
# Senston Tennis Rackets for Adults 27 inch Tennis Racquets - 2 Player Tennis Racket Set with 3balls,2 Grips, 2 Vibration Dampers
#
# Veken French Press Coffee Maker (34 oz), 304 Stainless Steel Coffee Press with 4 Filter Screens, Durable Easy Clean Heat Resistant Borosilicate Glass - 100% BPA Free, Black
#
# Uinkit Hot Thermal Laminating Pouches 5Mil Thick for Extra Protection 11.5x17.5 inches Laminating Sheets for Sealed 11x17inches Document and Photo 50 Pack A3 Menu Taloid Size
#
# ADOME Crop Top for Women Mesh Tee Shirt Plus Size Sheer Blouse Long/Short Sleeve Black XX-Large
#
# LB World Map Tapestry Wall Hanging Various Cartoon Animals Tapestrise World Distribution Map Wall Decor Blanket for Kids Bedroom Living Room Dorm Decor, 60Wx40H inches
#
# Grateful Dead: The Illustrated Trip
#
# Pool RX 101001 6 Month Algaecide Blue Treats 7.5k-20k gallons, Single, Unit
#
# Thermos The Rock Vacuum Insulated 1 Liter Beverage Bottle, stainless steel/black, 1.1 quart (2510TRI2)
#
# Easton DELUXE Baseball Pant | Youth Sizes | Solid
#
# SHARP 24 in 1.2 cu. ft. Sharp IoT + Easy Wave Open, Stainless Steel Convection Microwave Drawer
#
# 2 Pack Adjustable Bib Apron 2 Pockets Cooking Kitchen Bar Chef Apron
#
# 16 Pack Adjustable Mask Lanyard For Adults/Kids - Handy & Convenient Safety Mask Holder & Hanger - Comfortable Around The Neck Facemask Rest & Ear Saver - No More Lost/Dropped Masks 8 colours Red+blue
#
# ZORRI Sports Water Bottle, 400/500/700ml/1L, BPA Free Leak Proof Tritan Lightweight Bottles for Outdoors,Camping,Cycling,Fitness,Gym,Yoga- Kids/ Adults Drink Bottles with Filter, Lockable Pop Open Lid
#
# YETI Rambler 20 oz Stainless Steel Vacuum Insulated Tumbler w/MagSlider Lid
#
# PUR CR1100CV Classic Water Filter Pitcher Filtration System, 11 Cup
#
# GKOLED 12 Inch LED Hardscape Lighting, Low Voltage Retaining Wall Lights, LED Paver Step Light, 4W 12V AC/DC, 22pcs LED Chips, 2700K Warm White (4-Pack)
#
# Paper Clever Party Unicorn Diaper Raffle Tickets - Baby Shower Games Girls – Star and Moon Invitation Insert Cards Pink - Guests Fill-In to Win Prize Drawings (25 Pack) Size 2x4
#
# SHEKINI Women Floral Lace Bra Padded Breathable Bralette Halter Bra Wire Free Racerback Bra
#
# Universal Hard Saddle Bags Detachable Mounting Brackets Compatible with 8mm Mounting Holes Quick Release
#
# Simple Joys by Carter's Toddlers and Baby Girls' Snug-Fit Footless Cotton Pajamas, Pack of 3
#
# STEP 1 Shoe Stretchers, 1 Pair, Relieve Callus, Corn, Hammertoe, & Bunion Discomfort
#
# Bloccs Waterproof Cast Protector for Shower Arm - #CFA73-XS - Child Full Arm - (Extra Small)
#
# Nike Men's Race Running Shoe
#
#
#
#
#
# PinkSheep Little Girl Jewel Rings in Box, Adjustable, No Duplication, Girl Pretend Play and Dress Up Rings (24 Surface Ring)
#
# Makeup Cosmetic Bags - Stars Can't Shine Without Darkness - Funny Cotton Zipper Pouch Travel Bag Toiletry Make-Up Case for Women Stoner Friend Sister Bestie Valentine's Day Birthday Gifts
#
# Five Star Advance Spiral Notebooks, 3-Subject, College Ruled Paper, 11" x 8-1/2", 150 Sheets, With Spiral Guard and Movable Dividers, Red (73134)
#
# SOLOYEE Newborn Baby Girl Clothes Infant Girls Romper Ruffled Solid Long Sleeve Jumpsuit 0-18M Baby Outfits
#
# sublue WhiteShark Mix Underwater Scooter Dual Propellers with Camera Mount for Scuba Diving Snorkeling (US Version)

# %%
["Phone Accessories", "Clothing", " Supplies", "Book", "Clothing", "Shoes", "Ornaments", "Clothing",
 "Shoes", "Clothing", "Shoes"]

# %%
dataset_prompt_eng.add_column()
# Out:
# Dataset({
#     features: ['docid', 'title', 'text'],
#     num_rows: 50
# })

# %%
type(dataset)
# Out:
# datasets.arrow_dataset.Dataset

# %% [markdown]
# <a name='2'></a>
# ## 2 - Aplicando Full Fine-Tuning

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Preprocessando o Dialog-Summary Dataset
#
# Precisamos converter os pares de resumo de diálogo (prompt-response) em instruções explícitas para o LLM. Vamos anexar uma instrução ao início da caixa de diálogo com `Resumir a seguinte conversa` e ao início do resumo com `Resumo` da seguinte forma:
#
# Training prompt (dialogue):
# ```
# Summarize the following conversation.
#
#     Chris: This is his part of the conversation.
#     Antje: This is her part of the conversation.
#
# Summary:
# ```
#
# Training response (summary):
# ```
# Both Chris and Antje participated in the conversation.
# ```
#
# Em seguida, vamos preprocessar o conjunto de dados de resposta de prompt em tokens e extrair seus `input_ids` (1 por token).

# %%
def tokenize_function(example):
    start_prompt = 'Extract the product category from the product title.\n\n'
    end_prompt = '\n\nCategory: '
    prompt = [start_prompt + dialogue + end_prompt for dialogue in example["dialogue"]]
    example['input_ids'] = tokenizer(prompt, padding="max_length", truncation=True, return_tensors="pt").input_ids
    example['labels'] = tokenizer(example["summary"], padding="max_length", truncation=True, return_tensors="pt").input_ids

    return example

# Na verdade, o conjunto de dados contém 3 divisões: treino, validação, teste.
# O código tokenize_function está manipulando todos os dados em todas as divisões em lotes.
tokenized_datasets = dataset.map(tokenize_function, batched=True)
tokenized_datasets = tokenized_datasets.remove_columns(['id', 'topic', 'dialogue', 'summary',])
# Out:
# Loading cached processed dataset at /home/bruno/.cache/huggingface/datasets/knkarthick___csv/knkarthick--dialogsum-c8fac5d84cd35861/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-9a0a8356ed329662.arrow
# Loading cached processed dataset at /home/bruno/.cache/huggingface/datasets/knkarthick___csv/knkarthick--dialogsum-c8fac5d84cd35861/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-4a7759ff139dac8d.arrow
# Loading cached processed dataset at /home/bruno/.cache/huggingface/datasets/knkarthick___csv/knkarthick--dialogsum-c8fac5d84cd35861/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-44843119538026ee.arrow

# %% [markdown]
# Para poupar tempo, vamos pegar um sample do conjunto de dados:

# %%
tokenized_datasets = tokenized_datasets.filter(lambda example, index: index % 100 == 0, with_indices=True)
# Out:
# Loading cached processed dataset at /home/bruno/.cache/huggingface/datasets/knkarthick___csv/knkarthick--dialogsum-c8fac5d84cd35861/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-5fe7fa0f459c48fe.arrow
# Loading cached processed dataset at /home/bruno/.cache/huggingface/datasets/knkarthick___csv/knkarthick--dialogsum-c8fac5d84cd35861/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-4471a715ac15ad6c.arrow
# Loading cached processed dataset at /home/bruno/.cache/huggingface/datasets/knkarthick___csv/knkarthick--dialogsum-c8fac5d84cd35861/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-f3a440617082d3f8.arrow

# %% [markdown]
# Verifica as formas de todas as três partes do conjunto de dados:

# %%
print(f"Shapes of the datasets:")
print(f"Training: {tokenized_datasets['train'].shape}")
print(f"Validation: {tokenized_datasets['validation'].shape}")
print(f"Test: {tokenized_datasets['test'].shape}")

print(tokenized_datasets)
# Out:
# Shapes of the datasets:
# Training: (125, 2)
# Validation: (5, 2)
# Test: (15, 2)
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 125
#     })
#     test: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 15
#     })
#     validation: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 5
#     })
# })

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Fine-Tune do modelo com o conjunto de dados pré-processado
#
# Vamos utilizar a classe interna Hugging Face `Trainer` (consulte a documentação [aqui](https://huggingface.co/docs/transformers/main_classes/trainer)). Passaremos o conjunto de dados pré-processado com referência ao modelo original. Outros parâmetros de treinamento são encontrados experimentalmente e não há necessidade de entrar em detalhes sobre eles no momento.

# %%
output_dir = f'./dialogue-summary-training-{str(int(time.time()))}'

training_args = TrainingArguments(
    output_dir=output_dir,
    learning_rate=1e-5,
    num_train_epochs=1,
    weight_decay=0.01,
    logging_steps=1,
    max_steps=1
)

trainer = Trainer(
    model=original_model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['validation']
)

# %%
tokenized_datasets['validation']
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 5
# })

# %%
tokenized_datasets["train"]
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 125
# })

# %%
#trainer.train()

# %% [markdown]
# Treinar uma versão "fully fine-tuned" do modelo levaria algumas horas em uma GPU. Para economizar tempo, estarei somente lendo um ponto de checkpoint do modelo fully fine-tuned para usar no restante deste notebook. Esse modelo será chamado de **instruct model**.

# %% [markdown]
# Crie uma instância da classe `AutoModelForSeq2SeqLM` para o instruct model:

# %%
instruct_model = AutoModelForSeq2SeqLM.from_pretrained("./flan-dialogue-summary-checkpoint", torch_dtype=torch.bfloat16)

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Avaliação do modelo qualitativamente (avaliação humana)
#
# Como em muitos aplicativos GenAI, uma abordagem qualitativa em que você se pergunta: "Meu modelo está se comportando da maneira que deveria?" geralmente é um bom ponto de partida. No exemplo abaixo (o mesmo com o qual iniciamos esse notebook), podemos ver como o instruct model é capaz de criar um resumo razoável do diálogo em comparação com o original, que foi incapaz de entender o que está sendo solicitado.

# %%
index = 200
dialogue = dataset['test'][index]['dialogue']
human_baseline_summary = dataset['test'][index]['summary']

prompt = f"""
Summarize the following conversation.

{dialogue}

Summary:
"""

input_ids = tokenizer(prompt, return_tensors="pt").input_ids

original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)

instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)

print(dash_line)
print(f'BASELINE HUMAN SUMMARY:\n{human_baseline_summary}')
print(dash_line)
print(f'ORIGINAL MODEL:\n{original_model_text_output}')
print(dash_line)
print(f'INSTRUCT MODEL:\n{instruct_model_text_output}')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 15
#       5 prompt = f"""
#       6 Summarize the following conversation.
#       7
#    (...)
#      10 Summary:
#      11 """
#      13 input_ids = tokenizer(prompt, return_tensors="pt").input_ids
# ---> 15 original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
#      16 original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)
#      18 instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/transformers/generation/utils.py:1268, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, **kwargs)
#    1260         logger.warning(
#    1261             "A decoder-only architecture is being used, but right-padding was detected! For correct "
#    1262             "generation results, please set `padding_side='left'` when initializing the tokenizer."
#    1263         )
#    1265 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1266     # if model is encoder decoder encoder_outputs are created
#    1267     # and added to `model_kwargs`
# -> 1268     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1269         inputs_tensor, model_kwargs, model_input_name
#    1270     )
#    1272 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    1273 if self.config.is_encoder_decoder:
#
# File ~/.local/lib/python3.10/site-packages/transformers/generation/utils.py:634, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name)
#     632 encoder_kwargs["return_dict"] = True
#     633 encoder_kwargs[model_input_name] = inputs_tensor
# --> 634 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     636 return model_kwargs
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:973, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     971 if inputs_embeds is None:
#     972     assert self.embed_tokens is not None, "You have to initialize the model with valid token embeddings"
# --> 973     inputs_embeds = self.embed_tokens(input_ids)
#     975 batch_size, seq_length = input_shape
#     977 # required mask seq length can be calculated via length of past
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/sparse.py:160, in Embedding.forward(self, input)
#     159 def forward(self, input: Tensor) -> Tensor:
# --> 160     return F.embedding(
#     161         input, self.weight, self.padding_idx, self.max_norm,
#     162         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/functional.py:2210, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2204     # Note [embedding_renorm set_grad_enabled]
#    2205     # XXX: equivalent to
#    2206     # with torch.no_grad():
#    2207     #   torch.embedding_renorm_
#    2208     # remove once script supports set_grad_enabled
#    2209     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2210 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument index in method wrapper__index_select)

# %% [markdown]
# <a name='2.4'></a>
# ### 2.4 - Avaliação do modelo quantitativamente (com a métrica ROUGE)
#
# A [métrica ROUGE](https://en.wikipedia.org/wiki/ROUGE_(metric)) ajuda a quantificar a validade dos resumos produzidos por modelos. Ele compara resumos a um resumo de "linha de base" que geralmente é criado por um ser humano. Embora não seja perfeito, indica o aumento geral na eficácia do resumo que conseguimos com o fine tune.

# %%
rouge = evaluate.load('rouge')

# %% [markdown]
# Vamos gerar as saídas para a amostra do conjunto de dados de teste (apenas 10 diálogos e resumos para economizar tempo) e salvar os resultados.

# %%
dialogues = dataset['test'][0:10]['dialogue']
human_baseline_summaries = dataset['test'][0:10]['summary']

original_model_summaries = []
instruct_model_summaries = []

for _, dialogue in enumerate(dialogues):
    prompt = f"""
Summarize the following conversation.

{dialogue}

Summary: """
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids

    original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)
    original_model_summaries.append(original_model_text_output)

    instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)
    instruct_model_summaries.append(instruct_model_text_output)

zipped_summaries = list(zip(human_baseline_summaries, original_model_summaries, instruct_model_summaries))

df = pd.DataFrame(zipped_summaries, columns = ['human_baseline_summaries', 'original_model_summaries', 'instruct_model_summaries'])
df
# Out:
#                             human_baseline_summaries
# 0  Ms. Dawson helps #Person1# to write a memo to ...  \
# 1  In order to prevent employees from wasting tim...
# 2  Ms. Dawson takes a dictation for #Person1# abo...
# 3  #Person2# arrives late because of traffic jam....
# 4  #Person2# decides to follow #Person1#'s sugges...
# 5  #Person2# complains to #Person1# about the tra...
# 6  #Person1# tells Kate that Masha and Hero get d...
# 7  #Person1# tells Kate that Masha and Hero are g...
# 8  #Person1# and Kate talk about the divorce betw...
# 9  #Person1# and Brian are at the birthday party ...
#
#                             original_model_summaries
# 0     #Person1#: I need to take a dictation for you.  \
# 1     #Person1#: I need to take a dictation for you.
# 2     #Person1#: I need to take a dictation for you.
# 3  The traffic jam at the Carrefour intersection ...
# 4  The traffic jam at the Carrefour intersection ...
# 5  The traffic jam at the Carrefour intersection ...
# 6               Masha and Hero are getting divorced.
# 7               Masha and Hero are getting divorced.
# 8               Masha and Hero are getting divorced.
# 9  #Person1#: Happy birthday, Brian. #Person2#: I...
#
#                             instruct_model_summaries
# 0  #Person1# asks Ms. Dawson to take a dictation ...
# 1  #Person1# asks Ms. Dawson to take a dictation ...
# 2  #Person1# asks Ms. Dawson to take a dictation ...
# 3  #Person2# got stuck in traffic again. #Person1...
# 4  #Person2# got stuck in traffic again. #Person1...
# 5  #Person2# got stuck in traffic again. #Person1...
# 6  Masha and Hero are getting divorced. Kate can'...
# 7  Masha and Hero are getting divorced. Kate can'...
# 8  Masha and Hero are getting divorced. Kate can'...
# 9  Brian's birthday is coming. #Person1# invites ...

# %% [markdown]
# Avaliando os modelos computando as métricas ROUGE, observe a melhora nos resultados!

# %%
original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)
# Out:
# ORIGINAL MODEL:
# {'rouge1': 0.24089921652421653, 'rouge2': 0.11769053708439897, 'rougeL': 0.22001958689458687, 'rougeLsum': 0.22134175465057818}
# INSTRUCT MODEL:
# {'rouge1': 0.3839073578147069, 'rouge2': 0.1605940055118149, 'rougeL': 0.285893894130932, 'rougeLsum': 0.2876203213812496}

# %% [markdown]
# O arquivo `data/dialogue-summary-training-results.csv` contém uma lista pré-preenchida de todos os resultados do modelo que você pode usar para avaliar em uma seção maior de dados. Vamos fazer isso para cada um dos modelos:

# %%
results = pd.read_csv("data/dialogue-summary-training-results.csv")

human_baseline_summaries = results['human_baseline_summaries'].values
original_model_summaries = results['original_model_summaries'].values
instruct_model_summaries = results['instruct_model_summaries'].values

original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)
# Out:
# ORIGINAL MODEL:
# {'rouge1': 0.2334158581572823, 'rouge2': 0.07603964187010573, 'rougeL': 0.20145520923859048, 'rougeLsum': 0.20145899339006135}
# INSTRUCT MODEL:
# {'rouge1': 0.42161291557556113, 'rouge2': 0.18035380596301792, 'rougeL': 0.3384439349963909, 'rougeLsum': 0.33835653595561666}

# %% [markdown]
# Os resultados mostram uma melhoria substancial em todas as métricas ROUGE:

# %%
print("Absolute percentage improvement of INSTRUCT MODEL over ORIGINAL MODEL")

improvement = (np.array(list(instruct_model_results.values())) - np.array(list(original_model_results.values())))
for key, value in zip(instruct_model_results.keys(), improvement):
    print(f'{key}: {value*100:.2f}%')
# Out:
# Absolute percentage improvement of INSTRUCT MODEL over ORIGINAL MODEL
# rouge1: 18.82%
# rouge2: 10.43%
# rougeL: 13.70%
# rougeLsum: 13.69%

# %% [markdown]
# <a name='3'></a>
# ## 3 - Parameter Efficient Fine-Tuning (PEFT)
#
# Agora, vamos executar o **(PEFT)** em oposição ao "fully fine tune" como fizemos acima. O PEFT é uma forma de fine tune de instrução, que é muito mais eficiente do que o fully fine tune - com resultados de avaliação comparáveis, como você verá em breve.
#
# PEFT é um termo genérico que inclui o **Low-Rank Adaptation (LoRA)** e ajuste de prompt (que NÃO É O MESMO que engenharia de prompt!). Na maioria dos casos, quando alguém diz PEFT, geralmente significa LoRA. O LoRA, em um nível muito alto, permite ao usuário ajustar seu modelo usando menos recursos de computação (em alguns casos, uma única GPU). Após o fine tue para uma tarefa ou caso de uso com LoRA, o resultado é que o LLM original permanece inalterado e surge um “adaptador LoRA” recém-treinado. Este adaptador LoRA é muito, muito menor que o LLM original - da ordem de um único dígito % do tamanho original do LLM (MBs vs GBs).
#
# Dito isso, no momento da inferência, o adaptador LoRA precisa ser reunido e combinado com seu LLM original para atender à solicitação de inferência. O benefício, no entanto, é que muitos adaptadores LoRA podem reutilizar o LLM original, o que reduz os requisitos gerais de memória ao atender a várias tarefas e casos de uso.

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Configurando o modelo PEFT/LoRA para Fine-Tuning
#
# Precisamos configurar o modelo PEFT/LoRA para fine tune com um novo adaptador de camada/parâmetro. Usando PEFT/LoRA, estamos congelando a LLM subjacente e apenas treinando o adaptador. Dê uma olhada na configuração do LoRA abaixo. Observe o hiperparâmetro rank (`r`), que define o rank/dimensão do adaptador a ser treinado.

# %%
from peft import LoraConfig, get_peft_model, TaskType

lora_config = LoraConfig(
    r=32, # Rank
    lora_alpha=32,
    target_modules=["q", "v"],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.SEQ_2_SEQ_LM # FLAN-T5
)

# %% [markdown]
# Adicione camadas/parâmetros do adaptador LoRA ao LLM original a ser treinado.

# %%
peft_model = get_peft_model(original_model,
                            lora_config)
print(print_number_of_trainable_model_parameters(peft_model))
# Out:
# trainable model parameters: 3538944
# all model parameters: 251116800
# percentage of trainable model parameters: 1.41%

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Treinando o adaptador PEFT
#
# Vamos definir os argumentos de treinamento e criar a instância `Trainer`.

# %%
output_dir = f'./peft-dialogue-summary-training-{str(int(time.time()))}'

peft_training_args = TrainingArguments(
    output_dir=output_dir,
    auto_find_batch_size=True,
    learning_rate=1e-3, # Higher learning rate than full fine-tuning.
    num_train_epochs=1,
    logging_steps=1,
    max_steps=1
)

peft_trainer = Trainer(
    model=peft_model,
    args=peft_training_args,
    train_dataset=tokenized_datasets["train"],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb Cell 54 line 1
#       <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> output_dir = f'./peft-dialogue-summary-training-{str(int(time.time()))}'
#       <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=2'>3</a> peft_training_args = TrainingArguments(
#       <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=3'>4</a>     output_dir=output_dir,
#       <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=4'>5</a>     auto_find_batch_size=True,
#    (...)
#       <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=8'>9</a>     max_steps=1
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=9'>10</a> )
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=11'>12</a> peft_trainer = Trainer(
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=12'>13</a>     model=peft_model,
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=13'>14</a>     args=peft_training_args,
# ---> <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=14'>15</a>     train_dataset=tokenized_datasets["train"],
#      <a href='vscode-notebook-cell:/home/bruno/BRUNO_DIFRANCO_DDF_DATAANALYST_102023/01-10-2023-llm.ipynb#X66sZmlsZQ%3D%3D?line=15'>16</a> )
#
# NameError: name 'tokenized_datasets' is not defined

# %%
#peft_trainer.train()

#peft_model_path="./peft-dialogue-summary-checkpoint-local"

#peft_trainer.model.save_pretrained(peft_model_path)
#tokenizer.save_pretrained(peft_model_path)
# Out:
# ('./peft-dialogue-summary-checkpoint-local/tokenizer_config.json',
#  './peft-dialogue-summary-checkpoint-local/special_tokens_map.json',
#  './peft-dialogue-summary-checkpoint-local/tokenizer.json')

# %% [markdown]
# Em seguida, vamos carregar uma versão com o Lora já aplicado. Perceba a diferença no tamanho do arquivo!

# %% [markdown]
# Vamos agora preparar o modelo adicionando um adaptador ao FLAN-T5 original. Você está configurando `is_trainable=False` porque o plano é apenas realizar inferência com este modelo PEFT. Se você estivesse preparando o modelo para treinamento adicional, definiria `is_trainable=True`.

# %%
from peft import PeftModel, PeftConfig

peft_model_base = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base", torch_dtype=torch.bfloat16)
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")

peft_model = PeftModel.from_pretrained(peft_model_base,
                                       './peft-dialogue-summary-checkpoint-from-s3/',
                                       torch_dtype=torch.bfloat16,
                                       is_trainable=False)

# %% [markdown]
# O número de parâmetros treináveis ​​será `0` devido à configuração `is_trainable=False`:

# %%
print(print_number_of_trainable_model_parameters(peft_model))
# Out:
# trainable model parameters: 0
# all model parameters: 251116800
# percentage of trainable model parameters: 0.00%

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - Avalie o modelo qualitativamente (avaliação humana)

# %%
index = 200
dialogue = dataset['test'][index]['dialogue']
baseline_human_summary = dataset['test'][index]['summary']

prompt = f"""
Summarize the following conversation.

{dialogue}

Summary: """

input_ids = tokenizer(prompt, return_tensors="pt").input_ids

original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)

instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)

peft_model_outputs = peft_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
peft_model_text_output = tokenizer.decode(peft_model_outputs[0], skip_special_tokens=True)

print(dash_line)
print(f'BASELINE HUMAN SUMMARY:\n{human_baseline_summary}')
print(dash_line)
print(f'ORIGINAL MODEL:\n{original_model_text_output}')
print(dash_line)
print(f'INSTRUCT MODEL:\n{instruct_model_text_output}')
print(dash_line)
print(f'PEFT MODEL: {peft_model_text_output}')
# Out:
# ---------------------------------------------------------------------------------------------------
# BASELINE HUMAN SUMMARY:
# #Person1# teaches #Person2# how to upgrade software and hardware in #Person2#'s system.
# ---------------------------------------------------------------------------------------------------
# ORIGINAL MODEL:
# #Person1#: I'm thinking of upgrading my computer.
# ---------------------------------------------------------------------------------------------------
# INSTRUCT MODEL:
# #Person1# suggests #Person2# adding a painting program to #Person2#'s software and upgrading the hardware. #Person2# also wants to add a CD-ROM drive.
# ---------------------------------------------------------------------------------------------------
# PEFT MODEL: #Person1# recommends adding a painting program to #Person2#'s software and upgrading hardware. #Person2# also wants to upgrade the hardware because it's outdated now.

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Avalia os modelos quantitativamente (com a métrica ROUGE)

# %%
dialogues = dataset['test'][0:10]['dialogue']
human_baseline_summaries = dataset['test'][0:10]['summary']

original_model_summaries = []
instruct_model_summaries = []
peft_model_summaries = []

for idx, dialogue in enumerate(dialogues):
    prompt = f"""
Summarize the following conversation.

{dialogue}

Summary: """

    input_ids = tokenizer(prompt, return_tensors="pt").input_ids

    human_baseline_text_output = human_baseline_summaries[idx]

    original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)

    instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)

    peft_model_outputs = peft_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    peft_model_text_output = tokenizer.decode(peft_model_outputs[0], skip_special_tokens=True)

    original_model_summaries.append(original_model_text_output)
    instruct_model_summaries.append(instruct_model_text_output)
    peft_model_summaries.append(peft_model_text_output)

zipped_summaries = list(zip(human_baseline_summaries, original_model_summaries, instruct_model_summaries, peft_model_summaries))

df = pd.DataFrame(zipped_summaries, columns = ['human_baseline_summaries', 'original_model_summaries', 'instruct_model_summaries', 'peft_model_summaries'])
df
# Out:
#                             human_baseline_summaries
# 0  Ms. Dawson helps #Person1# to write a memo to ...  \
# 1  In order to prevent employees from wasting tim...
# 2  Ms. Dawson takes a dictation for #Person1# abo...
# 3  #Person2# arrives late because of traffic jam....
# 4  #Person2# decides to follow #Person1#'s sugges...
# 5  #Person2# complains to #Person1# about the tra...
# 6  #Person1# tells Kate that Masha and Hero get d...
# 7  #Person1# tells Kate that Masha and Hero are g...
# 8  #Person1# and Kate talk about the divorce betw...
# 9  #Person1# and Brian are at the birthday party ...
#
#                             original_model_summaries
# 0     #Person1#: I need to take a dictation for you.  \
# 1     #Person1#: I need to take a dictation for you.
# 2     #Person1#: I need to take a dictation for you.
# 3  The traffic jam at the Carrefour intersection ...
# 4  The traffic jam at the Carrefour intersection ...
# 5  The traffic jam at the Carrefour intersection ...
# 6               Masha and Hero are getting divorced.
# 7               Masha and Hero are getting divorced.
# 8               Masha and Hero are getting divorced.
# 9  #Person1#: Happy birthday, Brian. #Person2#: I...
#
#                             instruct_model_summaries
# 0  #Person1# asks Ms. Dawson to take a dictation ...  \
# 1  #Person1# asks Ms. Dawson to take a dictation ...
# 2  #Person1# asks Ms. Dawson to take a dictation ...
# 3  #Person2# got stuck in traffic again. #Person1...
# 4  #Person2# got stuck in traffic again. #Person1...
# 5  #Person2# got stuck in traffic again. #Person1...
# 6  Masha and Hero are getting divorced. Kate can'...
# 7  Masha and Hero are getting divorced. Kate can'...
# 8  Masha and Hero are getting divorced. Kate can'...
# 9  Brian's birthday is coming. #Person1# invites ...
#
#                                 peft_model_summaries
# 0  #Person1# asks Ms. Dawson to take a dictation ...
# 1  #Person1# asks Ms. Dawson to take a dictation ...
# 2  #Person1# asks Ms. Dawson to take a dictation ...
# 3  #Person2# got stuck in traffic and #Person1# s...
# 4  #Person2# got stuck in traffic and #Person1# s...
# 5  #Person2# got stuck in traffic and #Person1# s...
# 6  Kate tells #Person2# Masha and Hero are gettin...
# 7  Kate tells #Person2# Masha and Hero are gettin...
# 8  Kate tells #Person2# Masha and Hero are gettin...
# 9  Brian remembers his birthday and invites #Pers...

# %%
rouge = evaluate.load('rouge')

original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

peft_model_results = rouge.compute(
    predictions=peft_model_summaries,
    references=human_baseline_summaries[0:len(peft_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)
print('PEFT MODEL:')
print(peft_model_results)
# Out:
# ORIGINAL MODEL:
# {'rouge1': 0.24089921652421653, 'rouge2': 0.11769053708439897, 'rougeL': 0.22001958689458687, 'rougeLsum': 0.22134175465057818}
# INSTRUCT MODEL:
# {'rouge1': 0.3839073578147069, 'rouge2': 0.1605940055118149, 'rougeL': 0.285893894130932, 'rougeLsum': 0.2876203213812496}
# PEFT MODEL:
# {'rouge1': 0.3725351062275605, 'rouge2': 0.12138811933618107, 'rougeL': 0.27620639623170606, 'rougeLsum': 0.2758134870822362}

# %% [markdown]
# Observe que os resultados do modelo PEFT não são tão ruins, enquanto o processo de treinamento foi muito mais fácil!

# %% [markdown]
# Nós já calculamos a pontuação ROUGE no conjunto de dados completo, depois de carregar os resultados do arquivo `data/dialogue-summary-training-results.csv`. Vamso carregar agora os valores para o modelo PEFT e verificar seu desempenho em comparação com outros modelos.

# %%
human_baseline_summaries = results['human_baseline_summaries'].values
original_model_summaries = results['original_model_summaries'].values
instruct_model_summaries = results['instruct_model_summaries'].values
peft_model_summaries     = results['peft_model_summaries'].values

original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

peft_model_results = rouge.compute(
    predictions=peft_model_summaries,
    references=human_baseline_summaries[0:len(peft_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)
print('PEFT MODEL:')
print(peft_model_results)
# Out:
# ORIGINAL MODEL:
# {'rouge1': 0.2334158581572823, 'rouge2': 0.07603964187010573, 'rougeL': 0.20145520923859048, 'rougeLsum': 0.20145899339006135}
# INSTRUCT MODEL:
# {'rouge1': 0.42161291557556113, 'rouge2': 0.18035380596301792, 'rougeL': 0.3384439349963909, 'rougeLsum': 0.33835653595561666}
# PEFT MODEL:
# {'rouge1': 0.40810631575616746, 'rouge2': 0.1633255794568712, 'rougeL': 0.32507074586565354, 'rougeLsum': 0.3248950182867091}

# %% [markdown]
# Os resultados mostram uma melhoria menor em relação ao fully fine tune, mas os benefícios do PEFT geralmente superam as métricas de desempenho ligeiramente inferiores.
#
# Calcule a melhoria do PEFT em relação ao modelo original:

# %%
print("Absolute percentage improvement of PEFT MODEL over ORIGINAL MODEL")

improvement = (np.array(list(peft_model_results.values())) - np.array(list(original_model_results.values())))
for key, value in zip(peft_model_results.keys(), improvement):
    print(f'{key}: {value*100:.2f}%')
# Out:
# Absolute percentage improvement of PEFT MODEL over ORIGINAL MODEL
# rouge1: 17.47%
# rouge2: 8.73%
# rougeL: 12.36%
# rougeLsum: 12.34%

# %% [markdown]
# Agora calcule a melhoria do PEFT em relação a um modelo totalmente ajustado:

# %%
print("Absolute percentage improvement of PEFT MODEL over INSTRUCT MODEL")

improvement = (np.array(list(peft_model_results.values())) - np.array(list(instruct_model_results.values())))
for key, value in zip(peft_model_results.keys(), improvement):
    print(f'{key}: {value*100:.2f}%')
# Out:
# Absolute percentage improvement of PEFT MODEL over INSTRUCT MODEL
# rouge1: -1.35%
# rouge2: -1.70%
# rougeL: -1.34%
# rougeLsum: -1.35%

# %% [markdown]
# Aqui vemos uma pequena redução percentual nas métricas ROUGE em relação ao fully fine tune. No entanto, o treinamento requer muito menos recursos de computação e memória (geralmente apenas uma única GPU).
